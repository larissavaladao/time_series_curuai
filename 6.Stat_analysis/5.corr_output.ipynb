# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import glob

# %% [markdown]
# # Correlation Analysis of Watershed Variables
#
# This notebook computes pairwise correlations between environmental variables and TSS (Total Suspended Solids) for local and regional watersheds.
#
# Process overview:
# - Load merged time-series correlation CSVs from the `datasets/Parameters Time series/merged_df` directory.
# - Generate heatmap images for each correlation matrix (per watershed and water period).
# - Extract TSS-only correlation columns (coefficients and significance) and build merged CSV tables.
#
# Inputs: CSV files matching `*Watershed/corr_*.csv` in `data_directory`.
# Outputs: PNG heatmaps (`corr_*.png`) and merged TSS CSVs (`corr_TSS_*.csv`).

# %%
# Configure matplotlib visualization parameters for consistency across all plots
plt.rcParams['font.size'] = 16  # Base font size
plt.rcParams['xtick.labelsize'] = 11  # X-axis tick label size
plt.rcParams['ytick.labelsize'] = 11  # Y-axis tick label size
plt.rcParams['legend.fontsize'] = 14  # Legend font size

# %%
data_directory = r"C:\Users\l_v_v\Documents\GitHub\time_series_curuai\datasets\Parameters Time series\merged_df"

# %% [markdown]
# # Local Watershed Variables Correlation
#
# This section iterates through correlation CSVs for each watershed and water period. For each file it:
# - Reads the correlation matrix CSV into a dataframe,
# - Renames technical column names to more readable labels,
# - Plots a heatmap of the full correlation matrix using `seaborn.heatmap`,
# - Saves a high-resolution PNG to the same directory as the source CSV.
#
# Run this section to regenerate PNG heatmaps for any updated correlation CSVs in `data_directory`.

# %%
paths = sorted(glob.glob(os.path.join(data_directory, "*Watershed/corr_regional*.csv")) )
sel_paths = sorted([f for f in paths if ("corr_regional_" not in f)])
sel_paths
# Out:
# ['C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regionalF.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regionalHW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regionalLW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regionalR.csv']

# %%
for path in sel_paths:

    df = pd.read_csv(path)
    df = df.rename({"TSS_mean": "TSS", "area_km2": "Surface", "precipitation":"Precipitation", "mean_discharge":"Discharge",
                    "u_wind": "Eastward Wind","v_wind": "Northward Wind", "anthropogenic_km2": "Anthropic Area","Unnamed: 0": ""}, axis=1).set_index('')   
    df = df.rename({"TSS_mean": "TSS", "area_km2": "Surface", "precipitation":"Precipitation", "mean_discharge":"Discharge",
                    "u_wind": "Eastward Wind","v_wind": "Northward Wind", "anthropogenic_km2": "Anthropic Area"})
    filename = f'corr_{os.path.basename(path).split("_")[-1].split(".")[0]}.png'
    directory = os.path.dirname(path)
    print(f"Processing file: {filename}")
    print(df.head())
    plt.figure(figsize=(12,14))
    sns.heatmap(df, annot=True, cmap='coolwarm',cbar=False)
    plt.savefig(os.path.join(directory, filename),dpi=500)
    plt.show()
    
    plt.close()
# Out:
# Processing file: corr_regional.png
#                     TSS   Surface  Precipitation  Discharge  Eastward Wind  \
#
# TSS            1.000000 -0.649384      -0.135319  -0.137938      -0.014157
# Surface       -0.649384  1.000000       0.135871   0.080157       0.010296
# Precipitation -0.135319  0.135871       1.000000   0.011424      -0.075749
# Discharge     -0.137938  0.080157       0.011424   1.000000       0.021243
# Eastward Wind -0.014157  0.010296      -0.075749   0.021243       1.000000
#
#                Northward Wind  Anthropic Area
#
# TSS                 -0.048722       -0.109136
# Surface              0.004413        0.141432
# Precipitation       -0.125758        0.047886
# Discharge            0.034272       -0.052135
# Eastward Wind        0.215665       -0.132708
# Processing file: corr_regionalF.png
#                     TSS   Surface  Precipitation  Discharge  Eastward Wind  \
#
# TSS            1.000000 -0.424390      -0.129268  -0.344377       0.280488
# Surface       -0.424390  1.000000       0.187805   0.222540      -0.182927
# Precipitation -0.129268  0.187805       1.000000   0.279729       0.131707
# Discharge     -0.344377  0.222540       0.279729   1.000000      -0.249891
# Eastward Wind  0.280488 -0.182927       0.131707  -0.249891       1.000000
#
#                Northward Wind  Anthropic Area
#
# TSS                  0.209756       -0.334146
# Surface             -0.404878        0.490244
# Precipitation        0.017073        0.004878
# Discharge            0.048486        0.095729
# Eastward Wind        0.090244       -0.282927
# Processing file: corr_regionalHW.png
#                     TSS   Surface  Precipitation  Discharge  Eastward Wind  \
#
# TSS            1.000000 -0.122689       0.021849   0.087088      -0.109244
# Surface       -0.122689  1.000000       0.196639  -0.156758       0.092437
# Precipitation  0.021849  0.196639       1.000000  -0.226428       0.331092
# Discharge      0.087088 -0.156758      -0.226428   1.000000      -0.052253
# Eastward Wind -0.109244  0.092437       0.331092  -0.052253       1.000000
#
#                Northward Wind  Anthropic Area
#
# TSS                  0.166387       -0.139496
# Surface             -0.156303        0.351261
# Precipitation        0.055462        0.099160
# Discharge           -0.069670       -0.027868
# Eastward Wind       -0.156303        0.102521
# Processing file: corr_regionalLW.png
#                     TSS   Surface  Precipitation  Discharge  Eastward Wind  \
#
# TSS            1.000000 -0.496444      -0.251778  -0.086421      -0.103841
# Surface       -0.496444  1.000000       0.152205   0.206531       0.112376
# Precipitation -0.251778  0.152205       1.000000   0.212390       0.305832
# Discharge     -0.086421  0.206531       0.212390   1.000000       0.238755
# Eastward Wind -0.103841  0.112376       0.305832   0.238755       1.000000
#
#                Northward Wind  Anthropic Area
#
# TSS                  0.200569       -0.098151
# Surface             -0.038407       -0.194879
# Precipitation       -0.123755       -0.018492
# Discharge            0.027830       -0.215319
# Eastward Wind        0.257468       -0.194879
# Processing file: corr_regionalR.png
#                     TSS   Surface  Precipitation  Discharge  Eastward Wind  \
#
# TSS            1.000000 -0.500891      -0.105169   0.018236       0.062389
# Surface       -0.500891  1.000000      -0.008913  -0.083887      -0.019608
# Precipitation -0.105169 -0.008913       1.000000   0.032825       0.483066
# Discharge      0.018236 -0.083887       0.032825   1.000000       0.003647
# Eastward Wind  0.062389 -0.019608       0.483066   0.003647       1.000000
#
#                Northward Wind  Anthropic Area
#
# TSS                  0.254902       -0.176786
# Surface             -0.226381       -0.026786
# Precipitation       -0.001783        0.066072
# Discharge           -0.069298        0.007308
# Eastward Wind        0.044563       -0.033929

# %% [markdown]
# # Dataframe of correlation results only for TSS
#
# This section collects correlation coefficients and significance indicators specifically for TSS. For each water period it:
# - Finds correlation CSVs matching the period and excludes confidence-interval files (if present),
# - Extracts the `TSS_mean` column and renames columns to either `COEF` (coefficients) or `SIG` (significance),
# - Maps raw variable names to reader-friendly labels,
# - Concatenates the extracted TSS columns across files to produce a merged table, and
# - Saves the merged table as `corr_TSS_<period>.csv` in the same directory.
#
# Run this section after generating the correlation CSVs to produce consolidated TSS correlation reports.

# %%
cor = sorted(glob.glob(os.path.join(data_directory, "*Watershed/corr_*.csv"))) 
cor
# Out:
# ['C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_ci_local.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_localF.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_localHW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_localLW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_localR.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_ci_F.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_ci_HW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_ci_LW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_ci_R.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_p_F.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_p_HW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_p_LW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_p_R.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_se_F.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_se_HW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_se_LW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_se_R.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_p_local.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_se_local.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_si_local.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_ci_regional.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_p_regional.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regionalF.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regionalHW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regionalLW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regionalR.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_ci_F.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_ci_HW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_ci_LW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_ci_R.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_p_F.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_p_HW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_p_LW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_p_R.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_se_F.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_se_HW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_se_LW.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_se_R.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_se_regional.csv',
#  'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_si_regional.csv']

# %%
# Keep only files that DO NOT contain "pattern_to_exclude"
watersehds = ['regional', 'local']
water_period = ["LW","HW", "R", "F"]
for watershed in watersehds:
    cor_paths_w = sorted([f for f in cor if (watershed not in f)])
    cor_paths_w = sorted([f for f in cor_paths_w if ("ci" not in f)])

    for wp in water_period:
        cor_paths = sorted([f for f in cor_paths_w if (wp in f)])
        print(cor_paths)
        
        list_dfs = []

        for path in cor_paths:
            df_temp = pd.read_csv(path)
            
            df_temp = df_temp[['Unnamed: 0','TSS_mean']].copy()
            # print(df_temp.head())
            
            name_columns = f'{os.path.basename(path).split("_")[1]}'
            if "si" in name_columns:
                name_columns = "SIG"
                df_temp = df_temp.fillna(" ")
            if "csv" in name_columns:
                name_columns = "COEF"
            
            df_temp.columns = ["TSS Correlation", f'{name_columns.upper()}']
            df_temp = df_temp.loc[df_temp['TSS Correlation'] != "TSS_mean"].copy()
            rename_dict = {"area_km2": "Surface Area", "mean_chirps":"Precipitation", 
                    "mean_discharge":"Discharge", "u_wind": "Eastward Wind Speed",
                    "v_wind": "Northward Wind Speed", "anthropogenic_km2": "Anthropic Area"}
            df_temp['TSS Correlation'] = df_temp['TSS Correlation'].map(rename_dict)
            list_dfs.append(df_temp.set_index('TSS Correlation') )

        df_merged = pd.concat(list_dfs, axis=1)
        filename = f'corr_TSS_{os.path.basename(path).split("_")[-1].split(".")[0]}.csv'
        print(filename)
        directory = os.path.dirname(path)
        # print(directory)
        df_merged.to_csv(os.path.join(directory, filename))
        print(df_merged.head())
# Out:
# ['C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_localLW.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_p_LW.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_se_LW.csv']
# corr_TSS_LW.csv
#                           COEF     LOCAL     LOCAL
# TSS Correlation
# Surface Area         -0.496444  0.000011  0.144678
# NaN                  -0.194879  0.085006  0.163471
# Discharge            -0.023074  0.840294  0.166622
# Eastward Wind Speed  -0.192034  0.089658  0.163565
# Northward Wind Speed  0.189189  0.094512  0.163657
# ['C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_localHW.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_p_HW.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_se_HW.csv']
# corr_TSS_HW.csv
#                           COEF     LOCAL     LOCAL
# TSS Correlation
# Surface Area         -0.122689  0.299874  0.172763
# NaN                   0.213445  0.071297  0.170066
# Discharge            -0.040996  0.732614  0.173931
# Eastward Wind Speed  -0.008403  0.943392  0.174072
# Northward Wind Speed  0.146218  0.216635  0.172207
# ['C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_localR.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_p_R.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_se_R.csv']
# corr_TSS_R.csv
#                           COEF     LOCAL     LOCAL
# TSS Correlation
# Surface Area         -0.500891  0.000031  0.153002
# NaN                  -0.212121  0.077714  0.172754
# Discharge             0.014481  0.905364  0.176758
# Eastward Wind Speed  -0.030303  0.801029  0.176696
# Northward Wind Speed  0.244207  0.042260  0.171424
# ['C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_localF.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_p_F.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Local Watershed\\corr_local_se_F.csv']
# corr_TSS_F.csv
#                           COEF     LOCAL     LOCAL
# TSS Correlation
# Surface Area         -0.424390  0.000093  0.144993
# NaN                  -0.136585  0.208400  0.158627
# Discharge            -0.277258  0.011711  0.153850
# Eastward Wind Speed   0.090244  0.405881  0.159475
# Northward Wind Speed  0.192683  0.075956  0.157128
# ['C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regionalLW.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_p_LW.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_se_LW.csv']
# corr_TSS_LW.csv
#                           COEF  REGIONAL  REGIONAL
# TSS Correlation
# Surface Area         -0.496444  0.000011  0.144678
# NaN                  -0.251778  0.026066  0.161297
# Discharge            -0.086421  0.456172  0.166043
# Eastward Wind Speed  -0.103841  0.358750  0.165766
# Northward Wind Speed  0.200569  0.076289  0.163280
# ['C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regionalHW.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_p_HW.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_se_HW.csv']
# corr_TSS_HW.csv
#                           COEF  REGIONAL  REGIONAL
# TSS Correlation
# Surface Area         -0.122689  0.299874  0.172763
# NaN                   0.021849  0.853528  0.174036
# Discharge             0.087088  0.474930  0.173416
# Eastward Wind Speed  -0.109244  0.355959  0.173036
# Northward Wind Speed  0.166387  0.159741  0.171651
# ['C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_p_regional.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regionalF.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regionalHW.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regionalLW.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regionalR.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_p_F.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_p_HW.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_p_LW.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_p_R.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_se_F.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_se_HW.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_se_LW.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_se_R.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_se_regional.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_si_regional.csv']
# corr_TSS_regional.csv
#                                  P      COEF      COEF      COEF      COEF  \
# TSS Correlation
# Surface Area          1.112347e-31 -0.649384 -0.424390 -0.122689 -0.496444
# NaN                   1.466866e-02 -0.135319 -0.129268  0.021849 -0.251778
# Discharge             1.516086e-02 -0.137938 -0.344377  0.087088 -0.086421
# Eastward Wind Speed   7.984762e-01 -0.014157  0.280488 -0.109244 -0.103841
# Northward Wind Speed  3.795654e-01 -0.048722  0.209756  0.166387  0.200569
#
#                           COEF  REGIONAL  REGIONAL  REGIONAL  REGIONAL  \
# TSS Correlation
# Surface Area         -0.500891  0.000093  0.299874  0.000011  0.000031
# NaN                  -0.105169  0.233816  0.853528  0.026066  0.381769
# Discharge             0.018236  0.001809  0.474930  0.456172  0.881645
# Eastward Wind Speed   0.062389  0.009785  0.355959  0.358750  0.603862
# Northward Wind Speed  0.254902  0.053373  0.159741  0.076289  0.034015
#
#                       REGIONAL  REGIONAL  REGIONAL  REGIONAL        SE  SIG
# TSS Correlation
# Surface Area          0.144993  0.172763  0.144678  0.153002  0.062936  ***
# NaN                   0.158785  0.174036  0.161297  0.175796  0.081999    *
# Discharge             0.150333  0.173416  0.166043  0.176747  0.081969    *
# Eastward Wind Speed   0.153700  0.173036  0.165766  0.176432  0.082752
# Northward Wind Speed  0.156566  0.171651  0.163280  0.170937  0.082662
# ['C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regionalF.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_p_F.csv', 'C:\\Users\\l_v_v\\Documents\\GitHub\\time_series_curuai\\datasets\\Parameters Time series\\merged_df\\Regional Watershed\\corr_regional_se_F.csv']
# corr_TSS_F.csv
#                           COEF  REGIONAL  REGIONAL
# TSS Correlation
# Surface Area         -0.424390  0.000093  0.144993
# NaN                  -0.129268  0.233816  0.158785
# Discharge            -0.344377  0.001809  0.150333
# Eastward Wind Speed   0.280488  0.009785  0.153700
# Northward Wind Speed  0.209756  0.053373  0.156566
